# %% [markdown]
# # DEBUGGING
# # Can you find the error?
#
# Programming Lecture
#
# author: Prof I Lorscheid
#
# student: (please insert your name)

# %% [markdown]
# The following Python code boxes contain each errors and your task is to find the errors and correct the code.
#
# Please note there can be more than one error to be corrected + there are syntax and semantic errors possible!
#
# So please proceed step-by-step:
#
# * run the cell
# * identify the error
# * correct the error
# * document what you corrected for our discussion!
#
# Thank you and good luck :-)

# %%
# Exercise 1: If Statement
# Error: ________ (please document here)

age = 18
if ages = 18:
    print("You are 18 years old.")

# %%
# Exercise 2: For Loop
# Error: ________ (please document here)

for i in range(5)
    print("Number:"; i)

# %%
# Exercise 3: While Loop
# Error: ________ (please document here)

count = 0
while count < 5
    print("Count is", count)

# %%
# Exercise 4: List Comprehension
# Error: ________ (please document here)

squares = [x*x for x in range(10)
print(squares)

# %%
# Exercise 5: Lists
# Error: ________ (please document here)

numbers = [1, 2  3, 4,, 5]
print(numbers[5])

# %%
# Exercise 6: Dictionaries
# Error: ________ (please document here)

person = {'name': 'Alice', 'age': 25, 'gender' 'female'}
print(person[name])

# %%
# Exercise 7: Functions
# Error: ________ (please document here)

def add(a, b):
    result = a + b

print(add(10, 20))

# %%
# Exercise 8: Input
# Error: ________ (please document here)

age = input("Enter your age: ")
if age > 18:
    print("You are an adult.")

# %%
# Exercise 9: String Concatenation
# Error: ________ (please document here)

age = 25
message = "Your age is: " + age
print message)

# %%
# Exercise 10: Function with Default Parameters
# Error: ________ (please document here)

def greet(name, message="Hello"):
    print(message + ", "  name)

greet(message="Good morning", "Alice")
# Out:
#   File "<ipython-input-1-0fa5962e5f2e>", line 5
#     print(message + ", "  name)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Exercise 11: Find First Positive Number
# Error: ________ (please document here)

def first_positive(numbers):
    # Return the first positive number in the list
    for num in numbers:
        if num < 0
            return num

# Example usage
numbers = [-3, -2, -1, 0, 1, 2, 3]
result = first_positive(numbers
print("First positive number is:", result)

# %%
# Exercise 12: Count Even Numbers
# Error: ________ (please document here)

def count_even(numbers):
    # Return the count of even numbers in the list
    count = 0
    for nums in numbers:
        if num % 2 == 0:
            count = count + 1
    return count

# Example usage
numbers = [1, 2, 3, 4, 5, 6]
result = count_even(numbers)
print("Number of even numbers:", result)

# %%
# Exercise 13: Function Returning Multiple Values
# Error: ________ (please document here)

def filter_values(values):
    # Return values greater than 10
    filtered = []
    for value in values:
        if value > 10:
            filtered.append(value)
    return values

# Example usage
numbers = [5, 15, 10, 20, 25, 2]
result = filter_values(numbers)
print("Filtered values:", result)
